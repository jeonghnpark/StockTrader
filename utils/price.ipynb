# %%
import json
import logging
from json.decoder import JSONDecodeError

import requests
from requests.exceptions import RequestException

from ls_auth import api_manager, get_token_futures

logger = logging.getLogger(__name__)

TR = "g3101"
BASE_URL = "https://openapi.ls-sec.co.kr:8080"
PATH = "overseas-stock/market-data"
URL = f"{BASE_URL}/{PATH}"
G3101_MIN_INTERVAL_SEC = 0.34

# 거래소 프리픽스
EXCHANGE_PREFIX = {
    "81": "81",  # NYSE
    "82": "82",  # NASDAQ
}


def get_current(symbol, exchcd="82"):
    """
    g3101OutBlock dict 반환. 실패 시 None.
    
    Parameters:
    - symbol: 해외 주식 티커 (예: TSLA, AAPL) - 대문자로 자동 변환
    - exchcd: 거래소 코드 (81=뉴욕, 82=나스닥, 기본값 나스닥)
    
    API 문서 기반:
    - keysymbol: ex)82TSLA 형식 (거래소프리픽스 + 티커)
    - exchcd: 거래소 코드
    - symbol: 종목코드 (TSLA)
    """
    symbol = str(symbol).strip().upper()
    symbol ="AAPL"
    exchcd = str(exchcd).strip()
    exchcd = "82"
    
    
    # keysymbol = "ex)82TSLA" 형식으로 조합
    prefix = EXCHANGE_PREFIX.get(exchcd, "82")
    keysymbol = f"{prefix}{symbol}"
    keysymbol = "82AAPL"
    

    access_token = get_token_futures()
    header = {
        "content-type": "application/json; charset=utf-8",
        "Authorization": f"Bearer {access_token}",
        "tr_cd": TR,
        "tr_cont": "N",
        "tr_cont_key": "",
    }
    print(header)
    body = {
        f"{TR}InBlock": {
            "delaygb": "R",
            "keysymbol": keysymbol,
            "exchcd": exchcd,
            "symbol": symbol,
        }
    }

    api_manager.wait_for_next_call(TR, G3101_MIN_INTERVAL_SEC)
    try:
        print(header, body)
        # res = requests.post(URL, headers=header, data=json.dumps(body), timeout=30, verify=False)
        res = requests.post(URL, headers=header, data=json.dumps(body))
        
        res.raise_for_status()
        res_json = res.json()
        print(res_json)
        # logger.info("g3101 response: %s", res_json)
        
        # if f"{TR}OutBlock" not in res_json:
        #     logger.error("g3101: OutBlock not found: %s", res_json)
        #     return None
        return res_json[f"{TR}OutBlock"]
    except (RequestException, JSONDecodeError, KeyError) as e:
        logger.error("g3101 call error: %s", e)
        return None


print(get_current("TSLA", exchcd="82"))
# Out:
# {'content-type': 'application/json; charset=utf-8', 'Authorization': 'Bearer eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzUxMiJ9..nuoIG4UtScxfLD5ZioaRy-ExzTIyXlXtEuV9UMkouGT_9pGMUooWfzE_iKhIg-0_mHUEZhw8XexR8CbVR0E8CA', 'tr_cd': 'g3101', 'tr_cont': 'N', 'tr_cont_key': ''}
# {'content-type': 'application/json; charset=utf-8', 'Authorization': 'Bearer eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzUxMiJ9..nuoIG4UtScxfLD5ZioaRy-ExzTIyXlXtEuV9UMkouGT_9pGMUooWfzE_iKhIg-0_mHUEZhw8XexR8CbVR0E8CA', 'tr_cd': 'g3101', 'tr_cont': 'N', 'tr_cont_key': ''} {'g3101InBlock': {'delaygb': 'R', 'keysymbol': '82AAPL', 'exchcd': '82', 'symbol': 'AAPL'}}
# g3101 call error: 'g3101OutBlock'
# {'rsp_cd': '', 'rsp_msg': ''}
# None

# %%
"""LS Open API g3101 — 해외 주식 현재가·종목명(korname) 등."""

import json
import logging
from json.decoder import JSONDecodeError

import requests
from requests.exceptions import RequestException

from utils.ls_auth import api_manager, get_token_futures

logger = logging.getLogger(__name__)

TR = "g3101"
BASE_URL = "https://openapi.ls-sec.co.kr:8080"
PATH = "overseas-stock/market-data"
URL = f"{BASE_URL}/{PATH}"
G3101_MIN_INTERVAL_SEC = 0.34

# 거래소 프리픽스
EXCHANGE_PREFIX = {
    "81": "81",  # NYSE
    "82": "82",  # NASDAQ
}


def get_current(symbol, exchcd="82"):
    """
    g3101OutBlock dict 반환. 실패 시 None.
    
    Parameters:
    - symbol: 해외 주식 티커 (예: TSLA, AAPL) - 대문자로 자동 변환
    - exchcd: 거래소 코드 (81=뉴욕, 82=나스닥, 기본값 나스닥)
    
    API 문서 기반:
    - keysymbol: ex)82TSLA 형식 (거래소프리픽스 + 티커)
    - exchcd: 거래소 코드
    - symbol: 종목코드 (TSLA)
    """
    symbol = str(symbol).strip().upper()
    exchcd = str(exchcd).strip()
    
    # keysymbol = "ex)82TSLA" 형식으로 조합
    prefix = EXCHANGE_PREFIX.get(exchcd, "ex)82")
    keysymbol = f"{prefix}{symbol}"

    access_token = get_token_futures()
    header = {
        "content-type": "application/json; charset=utf-8",
        "Authorization": f"Bearer {access_token}",
        "tr_cd": TR,
        "tr_cont": "N",
        "tr_cont_key": "",
    }
    
    body = {
        f"{TR}InBlock": {
            "-keysymbol": keysymbol,
            "-exchcd": exchcd,
            "-symbol": symbol,
        }
    }

    api_manager.wait_for_next_call(TR, G3101_MIN_INTERVAL_SEC)
    try:
        res = requests.post(URL, headers=header, data=json.dumps(body), timeout=30, verify=False)
        res.raise_for_status()
        res_json = res.json()
        print(res_json)
        logger.info("g3101 response: %s", res_json)
        
        if f"{TR}OutBlock" not in res_json:
            logger.error("g3101: OutBlock not found: %s", res_json)
            return None
        return res_json[f"{TR}OutBlock"]
    except (RequestException, JSONDecodeError, KeyError) as e:
        logger.error("g3101 call error: %s", e)
        return None
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 10
#       6
#       7 import requests
#       8 from requests.exceptions import RequestException
#       9
# ---> 10 from utils.ls_auth import api_manager, get_token_futures
#      11
#      12 logger = logging.getLogger(__name__)
#      13
#
# ModuleNotFoundError: No module named 'utils'

# %%
get_current("TSLA",exchcd="81")
# Out:
# e:\dev\StockTrader\.venv\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'openapi.ls-sec.co.kr'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# g3101: OutBlock not found: {'rsp_cd': '00000', 'rsp_msg': '[g3101] 해당종목이 없습니다.'}

# %%
from api_auth import auth

# %%
token = auth.get_token_futures()
print(f"token successful {token}")
# Out:
# token successful eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzUxMiJ9..y0BUg0EInKyUaYFsby6hlVTJY_061qwS5eJ2QttBrrJkAo_Djhbu5cxwSFDKruuLGWjR4fBXFmtv2dysSlMoeg

# %%
import pandas as pd
from src.tr.futures.market_data import t2101
target_code = "A0166000"
target_code ="A7565000"

try:
    data =t2101.get_current(target_code)
    # print(data)
    # print(type(data))
    # print(len(data))
    if data:
        df = pd.DataFrame([data])
        display_cols = ['hname', 'price', 'sign' 'change', 'diff', 'volume']
        print("All columns", df.columns.tolist())
        display(df)
    else:
        print("No data found")
except Exception as e:
    print(f"API call error :{e}")
# Out:
# All columns ['hname', 'price', 'sign', 'change', 'jnilclose', 'diff', 'volume', 'value', 'mgjv', 'mgjvdiff', 'open', 'high', 'low', 'uplmtprice', 'dnlmtprice', 'high52w', 'low52w', 'basis', 'recprice', 'theoryprice', 'glyl', 'cbhprice', 'cblprice', 'lastmonth', 'jandatecnt', 'pricejisu', 'jisusign', 'jisuchange', 'jisudiff', 'kospijisu', 'kospisign', 'kospichange', 'kospidiff', 'listhprice', 'listlprice', 'delt', 'gama', 'ceta', 'vega', 'rhox', 'gmprice', 'gmsign', 'gmchange', 'gmdiff', 'theorypriceg', 'histimpv', 'impv', 'sbasis', 'ibasis', 'gmfutcode', 'actprice', 'greeks_time', 'greeks_confirm', 'danhochk', 'yeprice', 'jnilysign', 'jnilychange', 'jnilydrate', 'alloc_gubun', 'bjandatecnt', 'focode', 'dy_gubun', 'dy_uplmtprice', 'dy_dnlmtprice', 'updnstep_gubun', 'upstep', 'dnstep', 'uplmtprice_3rd', 'dnlmtprice_3rd', 'expct_ccls_q']
#            hname    price sign change jnilclose   diff  volume    value  \
# 0  미국달러 F 202605  1467.80    5   5.20   1473.00  -0.35  537537  7899562
#
#       mgjv  mgjvdiff     open     high      low uplmtprice dnlmtprice high52w  \
# 0  1130586      2436  1470.00  1472.10  1466.70    1539.20    1406.80       0
#
#   low52w basis recprice theoryprice    glyl cbhprice cblprice lastmonth  \
# 0      0     0  1473.00     1473.05  -0.357     0.00     0.00  20260518
#
#    jandatecnt pricejisu jisusign jisuchange jisudiff kospijisu kospisign  \
# 0          28   6388.47        2     169.38     2.72    962.26         2
#
#   kospichange kospidiff listhprice listlprice delt gama ceta vega rhox  \
# 0       26.51      2.83    1535.10    1375.00    0    0    0    0    0
#
#   gmprice gmsign gmchange gmdiff theorypriceg histimpv impv sbasis ibasis  \
# 0       0               0      0            0        0    0  -1.60   3.65
#
#   gmfutcode actprice greeks_time greeks_confirm danhochk  yeprice jnilysign  \
# 0                  0                                   0  1467.80         5
#
#   jnilychange jnilydrate alloc_gubun  bjandatecnt    focode dy_gubun  \
# 0        5.20      -0.35                       18  A7565000        2
#
#   dy_uplmtprice dy_dnlmtprice updnstep_gubun upstep dnstep uplmtprice_3rd  \
# 0       1539.20       1406.80              2     01     01        1539.20
#
#   dnlmtprice_3rd  expct_ccls_q
# 0        1406.80          4730

# %%
from src.tr.stock.market_data import t1101
target_code = "005930"
pd.set_option('display.max_columns', None)
try:
    data =t1101.get_current(target_code)
    # print(data)
    # print(type(data))
    # print(len(data))
    if data:
        df = pd.DataFrame([data])
        # display_cols = ['hname', 'price', 'sign' 'change', 'diff', 'volume']
        # print("All columns", df.columns.tolist())
        print(df)
    else:
        print("No data found")
except Exception as e:
    print(f"API call error :{e}")
# Out:
#   hname   price sign  change  diff    volume  jnilclose  offerho1  bidho1  \
# 0  삼성전자  219000    2    4500  2.10  16705245     214500    219000  218500
#
#    offerrem1  bidrem1  preoffercha1  prebidcha1  offerho2  bidho2  offerrem2  \
# 0     114378    67318             0           0    219500  218000     564319
#
#    bidrem2  preoffercha2  prebidcha2  offerho3  bidho3  offerrem3  bidrem3  \
# 0   109492             0           0    220000  217500    1065740    99860
#
#    preoffercha3  prebidcha3  offerho4  bidho4  offerrem4  bidrem4  \
# 0             0           0    220500  217000     133876   218621
#
#    preoffercha4  prebidcha4  offerho5  bidho5  offerrem5  bidrem5  \
# 0             0           0    221000  216500     202693   142076
#
#    preoffercha5  prebidcha5  offerho6  bidho6  offerrem6  bidrem6  \
# 0             0           0    221500  216000      87633   228374
#
#    preoffercha6  prebidcha6  offerho7  bidho7  offerrem7  bidrem7  \
# 0             0           0    222000  215500     174199    65079
#
#    preoffercha7  prebidcha7  offerho8  bidho8  offerrem8  bidrem8  \
# 0             0           0    222500  215000      67331   152365
#
#    preoffercha8  prebidcha8  offerho9  bidho9  offerrem9  bidrem9  \
# 0             0           0    223000  214500     153261    69344
#
#    preoffercha9  prebidcha9  offerho10  bidho10  offerrem10  bidrem10  \
# 0             0           0     223500   214000       55976     77414
#
#    preoffercha10  prebidcha10    offer      bid  preoffercha  prebidcha  \
# 0              0            0  2619406  1229943       124428     124428
#
#      hotime  yeprice  yevolume yesign  yechange yediff  tmoffer  tmbid  \
# 0  16000001        0         0      3         0   0.00     8453      0
#
#   ho_status  shcode  uplmtprice  dnlmtprice    open    high     low  \
# 0         2  005930      278500      150500  218000  220000  216000
#
#    krx_midprice  krx_offermidsumrem  krx_bidmidsumrem  krx_midsumrem  \
# 0             0                   0                 0              0
#
#   krx_midsumremgubun
# 0
